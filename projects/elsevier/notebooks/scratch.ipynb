# %%
from scholarly import scholarly

# %%
from scholarly import ProxyGenerator

# Set up a ProxyGenerator object to use free proxies
# This needs to be done only once per session
pg = ProxyGenerator()
pg.FreeProxies()
scholarly.use_proxy(pg)
# Out:
# ---------------------------------------------------------------------------
# MaxTriesExceededException                 Traceback (most recent call last)
# Cell In[15], line 10
#       7 scholarly.use_proxy(pg)
#       9 # Now search Google Scholar from behind a proxy
# ---> 10 search_query=scholarly.search_pubs('"CCS" OR "CCUS" OR "carbon capture and storage" OR "carbon capture use and storage"',
#      11                                    year_low=2010,year_high=2022)
#
# File ~/Library/Caches/pypoetry/virtualenvs/projects-7_KjhAaO-py3.11/lib/python3.11/site-packages/scholarly/_scholarly.py:160, in _Scholarly.search_pubs(self, query, patents, citations, year_low, year_high, sort_by, include_last_year, start_index)
#      97 """Searches by query and returns a generator of Publication objects
#      98
#      99 :param query: terms to be searched
#    (...)
#     155
#     156 """
#     157 url = self._construct_url(_PUBSEARCH.format(requests.utils.quote(query)), patents=patents,
# ...

# %%
# Now search Google Scholar from behind a proxy
search_query=scholarly.search_pubs('"CCS" OR "CCUS" OR "carbon capture and storage" OR "carbon capture use and storage"',
                                   year_low=2010,year_high=2022)

# %%
t=next(search_query)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 2
#       1 t=next(search_query)
# ----> 2 scholarly.bibtext(t)
#
# AttributeError: '_Scholarly' object has no attribute 'bibtext'

# %%
d=json.loads("{"status":"ok","message-type":"work-list","message-version":"1.0.0","message":{"facets":{},"total-results":9401,"items":[{"indexed":{"date-parts":[[2022,4,3]],"date-time":"2022-04-03T12:28:32Z","timestamp":1648988912238},"reference-count":0,"publisher":"Chinese Chemical Society","content-domain":{"domain":[],"crossmark-restriction":false},"DOI":"10.31635\/20965745","type":"journal","created":{"date-parts":[[2019,8,15]],"date-time":"2019-08-15T07:30:04Z","timestamp":1565854204000},"source":"Crossref","is-referenced-by-count":1,"title":["CCS Chemistry"],"prefix":"10.31635","member":"16648","language":"en","deposited":{"date-parts":[[2019,8,15]],"date-time":"2019-08-15T07:30:04Z","timestamp":1565854204000},"score":17.151588,"resource":{"primary":{"URL":"https:\/\/www.chinesechemsoc.org\/journal\/ccschem"}},"short-title":["CCS Chem"],"issued":{"date-parts":[[null]]},"references-count":0,"URL":"http:\/\/dx.doi.org\/10.31635\/20965745","ISSN":["2096-5745"],"issn-type":[{"value":"2096-5745","type":"electronic"}]},{"indexed":{"date-parts":[[2024,8,1]],"date-time":"2024-08-01T17:53:32Z","timestamp":1722534812272},"reference-count":88,"publisher":"Elsevier BV","license":[{"start":{"date-parts":[[2020,12,1]],"date-time":"2020-12-01T00:00:00Z","timestamp":1606780800000},"content-version":"tdm","delay-in-days":0,"URL":"https:\/\/www.elsevier.com\/tdm\/userlicense\/1.0\/"}],"funder":[{"DOI":"10.13039\/501100015635","name":"CCS","doi-asserted-by":"publisher"},{"DOI":"10.13039\/501100015635","name":"CCS","doi-asserted-by":"publisher"},{"DOI":"10.13039\/501100015635","name":"CCS","doi-asserted-by":"publisher"},{"DOI":"10.13039\/501100015635","name":"CCS","doi-asserted-by":"publisher"},{"DOI":"10.13039\/501100015635","name":"CCS","doi-asserted-by":"publisher"},{"DOI":"10.13039\/501100015635","name":"CCS","doi-asserted-by":"publisher"},{"DOI":"10.13039\/501100001809","name":"National Natural Science Foundation of China","doi-asserted-by":"publisher"},{"DOI":"10.13039\/501100012166","name":"National Key Research and Development Program of China","doi-asserted-by":"publisher"}],"content-domain":{"domain":["elsevier.com","sciencedirect.com"],"crossmark-restriction":true},"short-container-title":["Renewable and Sustainable Energy Reviews"],"published-print":{"date-parts":[[2020,12]]},"DOI":"10.1016\/j.rser.2020.110374","type":"journal-article","created":{"date-parts":[[2020,9,23]],"date-time":"2020-09-23T21:41:06Z","timestamp":1600897266000},"page":"110374","update-policy":"http:\/\/dx.doi.org\/10.1016\/elsevier_cm_policy","source":"Crossref","is-referenced-by-count":31,"special_numbering":"C","title":["Whether CCS technologies will exacerbate the water crisis in China? \u2014A full life-cycle analysis"],"prefix":"10.1016","volume":"134","author":[{"given":"Lin","family":"Yang","sequence":"first","affiliation":[]},{"given":"Haodong","family":"Lv","sequence":"additional","affiliation":[]},{"given":"Dalin","family":"Jiang","sequence":"additional","affiliation":[]},{"given":"Jingli","family":"Fan","sequence":"additional","affiliation":[]},{"given":"Xian","family":"Zhang","sequence":"additional","affiliation":[]},{"given":"Weijun","family":"He","sequence":"additional","affiliation":[]},{"given":"Jinsheng","family":"Zhou","sequence":"additional","affiliation":[]},{"given":"Wenjing","family":"Wu","sequence":"additional","affiliation":[]}],"member":"78","reference":[{"key":"10.1016\/j.rser.2020.110374_bib3","series-title":"Ministry of Science and Technology of the People's Republic of China (DSTSD-MST),The Administrative Center for China's Agenda 21(ACCA21). Technology roadmap study on carbon capture, utilization and storage in China","year":"2019"},{"key":"10.1016\/j.rser.2020.110374_bib4","series-title":"Global energy & CO2 status report","year":"2018"},{"key":"10.1016\/j.rser.2020.110374_bib5","series-title":"Annual report on the development of China's power industry 2019","year":"2019"},{"key":"10.1016\/j.rser.2020.110374_bib7","doi-asserted-by":"crossref","first-page":"499","DOI":"10.1016\/j.apenergy.2017.05.003","article-title":"Spatial and temporal synchronization of water and energy systems: towards a single integrated optimization model for long-term resource planning","volume":"210","author":"Khan","year":"2018","journal-title":"Appl Energy"},{"key":"10.1016\/j.rser.2020.110374_bib8","doi-asserted-by":"crossref","first-page":"792","DOI":"10.1038\/s41560-018-0236-7","article-title":"Decoupling between water use and thermoelectric power generation growth in China","volume":"3","author":"Zhang","year":"2018","journal-title":"Nature Energy"},{"key":"10.1016\/j.rser.2020.110374_bib9","series-title":"Chinese water resources bulletin 2019","year":"2019"},{"key":"10.1016\/j.rser.2020.110374_bib11","doi-asserted-by":"crossref","first-page":"2448","DOI":"10.1016\/j.egypro.2011.02.139","article-title":"Environmental evaluation of CCS using Life Cycle Assessment\u2013A synthesis report","volume":"4","author":"Marx","year":"2011","journal-title":"Energy Procedia"},{"key":"10.1016\/j.rser.2020.110374_bib13","doi-asserted-by":"crossref","first-page":"247","DOI":"10.1016\/j.enconman.2014.11.013","article-title":"Development of life cycle water-demand coefficients for coal-based power generation technologies","volume":"90","author":"Ali","year":"2015","journal-title":"Energy Convers Manag"},{"key":"10.1016\/j.rser.2020.110374_bib14","doi-asserted-by":"crossref","first-page":"91","DOI":"10.1016\/j.enconman.2015.12.075","article-title":"Life cycle energy use and GHG emission assessment of coal-based SNG and power cogeneration technology in China","volume":"112","author":"Li","year":"2016","journal-title":"Energy Convers Manag"},{"key":"10.1016\/j.rser.2020.110374_bib15","doi-asserted-by":"crossref","first-page":"59","DOI":"10.1016\/j.ijggc.2012.12.003","article-title":"Environmental impact assessment of CCS chains \u2013 lessons learned and limitations from LCA literature","volume":"13","author":"Corsten","year":"2013","journal-title":"International Journal of Greenhouse Gas Control"},{"key":"10.1016\/j.rser.2020.110374_bib16","doi-asserted-by":"crossref","first-page":"911","DOI":"10.1016\/j.ijggc.2011.03.012","article-title":"Comparative life cycle environmental assessment of CCS technologies","volume":"5","author":"Singh","year":"2011","journal-title":"International Journal of Greenhouse Gas Control"},{"key":"10.1016\/j.rser.2020.110374_bib17","doi-asserted-by":"crossref","first-page":"7437","DOI":"10.1016\/j.egypro.2014.11.780","article-title":"Life cycle assessment of a pulverized coal-fired power plant with CCS technology in Japan","volume":"63","author":"Tang","year":"2014","journal-title":"Energy Procedia"},{"key":"10.1016\/j.rser.2020.110374_bib18","doi-asserted-by":"crossref","first-page":"258","DOI":"10.1016\/j.apenergy.2018.05.013","article-title":"Life cycle energy-economic-CO2 emissions evaluation of biomass\/coal, with and without CO2 capture and storage, in a pulverized fuel combustion power plant in the United Kingdom","volume":"225","author":"Yi","year":"2018","journal-title":"Appl Energy"},{"key":"10.1016\/j.rser.2020.110374_bib19","doi-asserted-by":"crossref","first-page":"10","DOI":"10.1016\/j.jclepro.2017.03.225","article-title":"Life Cycle Assessment for supercritical pulverized coal power plants with post-combustion carbon capture and storage","volume":"157","author":"Petrescu","year":"2017","journal-title":"J Clean Prod"},{"key":"10.1016\/j.rser.2020.110374_bib20","doi-asserted-by":"crossref","first-page":"233","DOI":"10.1016\/j.jclepro.2017.05.011","article-title":"Environmental assessment of IGCC power plants with pre-combustion CO2 capture by chemical & calcium looping methods","volume":"158","author":"Petrescu","year":"2017","journal-title":"J Clean Prod"},{"key":"10.1016\/j.rser.2020.110374_bib21","doi-asserted-by":"crossref","first-page":"188","DOI":"10.1016\/j.jclepro.2017.03.026","article-title":"Life cycle assessment of co-firing coal and wood pellets in the Southeastern United States","volume":"150","author":"Morrison","year":"2017","journal-title":"J Clean Prod"},{"key":"10.1016\/j.rser.2020.110374_bib22","doi-asserted-by":"crossref","first-page":"153","DOI":"10.1016\/j.envsoft.2015.10.011","article-title":"Spatially-explicit water balance implications of carbon capture and sequestration","volume":"75","author":"Sathre","year":"2016","journal-title":"Environ Model Software"},{"key":"10.1016\/j.rser.2020.110374_bib23","first-page":"8940","article-title":"Potential impacts of electric power production utilizing natural gas, renewables and carbon capture and sequestration on U.S. Freshwater resources","volume":"47","author":"Tidwell","year":"2013","journal-title":"Environ Sci Technol"},{"key":"10.1016\/j.rser.2020.110374_bib24","doi-asserted-by":"crossref","first-page":"2479","DOI":"10.1021\/es1034443","article-title":"Water use at pulverized coal power plants with postcombustion carbon capture and storage","volume":"45","author":"Zhai","year":"2011","journal-title":"Environ Sci Technol"},{"key":"10.1016\/j.rser.2020.110374_bib25","doi-asserted-by":"crossref","first-page":"714","DOI":"10.1016\/j.enpol.2018.05.067","article-title":"Assessing carbon pollution standards: electric power generation pathways and their water impacts","volume":"120","author":"Lim-Wavde","year":"2018","journal-title":"Energy Pol"},{"key":"10.1016\/j.rser.2020.110374_bib26","doi-asserted-by":"crossref","first-page":"4221","DOI":"10.1016\/j.egypro.2011.02.370","article-title":"Active and integrated management of water resources throughout CO2 capture and sequestration operations","volume":"4","author":"Court","year":"2011","journal-title":"Energy Procedia"},{"key":"10.1016\/j.rser.2020.110374_bib27","doi-asserted-by":"crossref","first-page":"87","DOI":"10.1016\/j.ijggc.2012.12.019","article-title":"Modeling water use demands for thermoelectric power plants with CCS in selected Brazilian water basins","volume":"13","author":"Merschmann","year":"2013","journal-title":"International Journal of Greenhouse Gas Control"},{"key":"10.1016\/j.rser.2020.110374_bib28","doi-asserted-by":"crossref","first-page":"4511","DOI":"10.1016\/j.egypro.2013.06.357","article-title":"Feasibility of the combination of CO2 geological storage and saline water development in sedimentary basins of China","volume":"37","author":"Li","year":"2013","journal-title":"Energy Procedia"},{"key":"10.1016\/j.rser.2020.110374_bib29","series-title":"Annual report on the development of China's power industry 2010","year":"2010"},{"key":"10.1016\/j.rser.2020.110374_bib30","series-title":"Annual report on the development of China's power industry 2018","year":"2018"},{"key":"10.1016\/j.rser.2020.110374_bib31","series-title":"Chinese water resources bulletin 2017","year":"2017"},{"key":"10.1016\/j.rser.2020.110374_bib32","doi-asserted-by":"crossref","first-page":"939","DOI":"10.1007\/s11442-016-1308-x","article-title":"Water resource formation and conversion and water security in arid region of Northwest China","volume":"26","author":"Chen","year":"2016","journal-title":"J Geogr Sci"},{"key":"10.1016\/j.rser.2020.110374_bib36","doi-asserted-by":"crossref","first-page":"249","DOI":"10.1016\/j.ijggc.2015.11.029","article-title":"Life cycle water use of coal- and natural-gas-fired power plants with and without carbon capture and storage","volume":"44","author":"Ou","year":"2016","journal-title":"International Journal of Greenhouse Gas Control"},{"key":"10.1016\/j.rser.2020.110374_bib37","doi-asserted-by":"crossref","first-page":"113483","DOI":"10.1016\/j.apenergy.2019.113483","article-title":"Life cycle environmental impact assessment of fuel mix-based biomass co-firing plants with CO2 capture and storage","volume":"252","author":"Yang","year":"2019","journal-title":"Appl Energy"},{"key":"10.1016\/j.rser.2020.110374_bib38","doi-asserted-by":"crossref","first-page":"5653","DOI":"10.1016\/j.enpol.2010.05.013","article-title":"Performance and cost of wet and dry cooling systems for pulverized coal power plants with and without carbon capture and storage","volume":"38","author":"Zhai","year":"2010","journal-title":"Energy Pol"},{"key":"10.1016\/j.rser.2020.110374_bib39","doi-asserted-by":"crossref","first-page":"644","DOI":"10.1016\/j.apenergy.2018.06.028","article-title":"Balancing marine ecosystem impact and freshwater consumption with water-use fees in California's power markets: an evaluation of possibilities and trade-offs","volume":"226","author":"Bolorinos","year":"2018","journal-title":"Appl Energy"},{"key":"10.1016\/j.rser.2020.110374_bib40","doi-asserted-by":"crossref","first-page":"196","DOI":"10.1016\/j.apenergy.2019.04.023","article-title":"Water withdrawal and consumption reduction for electrical energy generation systems","volume":"248","author":"Nouri","year":"2019","journal-title":"Appl Energy"},{"key":"10.1016\/j.rser.2020.110374_bib41","doi-asserted-by":"crossref","first-page":"7187","DOI":"10.1016\/j.egypro.2014.11.754","article-title":"Reduction of freshwater usage of a coal fired power plant with CCS by applying a high level of integration of all water streams","volume":"63","author":"Hylkema","year":"2014","journal-title":"Energy Procedia"},{"key":"10.1016\/j.rser.2020.110374_bib42","doi-asserted-by":"crossref","first-page":"293","DOI":"10.1016\/j.egypro.2018.09.128","article-title":"Impact of virtual water flow with the energy product transfer on sustainable water resources utilization in the main coal-fired power energy bases of Northern China","volume":"152","author":"Gao","year":"2018","journal-title":"Energy Procedia"},{"key":"10.1016\/j.rser.2020.110374_bib43","doi-asserted-by":"crossref","first-page":"735","DOI":"10.1016\/j.apenergy.2016.07.002","article-title":"Balancing development of major coal bases with available water resources in China through 2020","volume":"194","author":"Shang","year":"2017","journal-title":"Appl Energy"},{"key":"10.1016\/j.rser.2020.110374_bib44","doi-asserted-by":"crossref","first-page":"643","DOI":"10.1016\/j.apenergy.2016.11.008","article-title":"China's energy-water nexus: assessing water conservation synergies of the total coal consumption cap strategy until 2050","volume":"210","author":"Shang","year":"2018","journal-title":"Appl Energy"},{"key":"10.1016\/j.rser.2020.110374_bib45","first-page":"114","article-title":"Estimation and trend analysis of water demand of energy industry in China","volume":"31","author":"Xiang","year":"2016","journal-title":"J Nat Resour"},{"key":"10.1016\/j.rser.2020.110374_bib46","doi-asserted-by":"crossref","first-page":"63","DOI":"10.1016\/j.esr.2014.08.001","article-title":"Greenhouse gas emissions reduction in China by cleaner coal technology towards 2020","volume":"7","author":"Zhao","year":"2015","journal-title":"Energy Strategy Reviews"},{"key":"10.1016\/j.rser.2020.110374_bib47","first-page":"454","article-title":"Spatial characteristics of coal transportation network in China during 1990-2014","volume":"33","author":"Zhu","year":"2018","journal-title":"J Nat Resour"},{"key":"10.1016\/j.rser.2020.110374_bib48","doi-asserted-by":"crossref","first-page":"97","DOI":"10.1016\/j.jclepro.2018.09.254","article-title":"Multivariate statistical assessment of ambient air pollution in two coalfields having different coal transportation strategy: a comparative study in Eastern India","volume":"207","author":"Yadav","year":"2019","journal-title":"J Clean Prod"},{"key":"10.1016\/j.rser.2020.110374_bib49","doi-asserted-by":"crossref","first-page":"2039","DOI":"10.1016\/j.rser.2010.03.008","article-title":"Life-cycle uses of water in U.S. electricity generation","volume":"14","author":"Fthenakis","year":"2010","journal-title":"Renew Sustain Energy Rev"},{"key":"10.1016\/j.rser.2020.110374_bib50","doi-asserted-by":"crossref","DOI":"10.1088\/1748-9326\/8\/1\/015031","article-title":"Life cycle water use for electricity generation: a review and harmonization of literature estimates","volume":"8","author":"Meldrum","year":"2013","journal-title":"Environ Res Lett"},{"key":"10.1016\/j.rser.2020.110374_bib51","doi-asserted-by":"crossref","first-page":"18","DOI":"10.1016\/j.esr.2014.12.001","article-title":"Carbon capture and coal consumption: implications of energy penalties and large scale deployment","volume":"7","author":"Thorbjornsson","year":"2015","journal-title":"Energy Strategy Reviews"},{"key":"10.1016\/j.rser.2020.110374_bib52","series-title":"Chapter 9 \u2013 transportation of shale gas and oil resources. Environmental and health issues in unconventional oil and gas development","author":"Smith","year":"2016"},{"key":"10.1016\/j.rser.2020.110374_bib53","doi-asserted-by":"crossref","first-page":"138","DOI":"10.1016\/j.eneco.2016.08.013","article-title":"Trade with endogenous transportation costs: the case of liquefied natural gas","volume":"59","author":"Oglend","year":"2016","journal-title":"Energy Econ"},{"key":"10.1016\/j.rser.2020.110374_bib54","doi-asserted-by":"crossref","first-page":"111","DOI":"10.1061\/(ASCE)1076-0342(2004)10:3(111)","article-title":"Greenhouse gas emissions from coal gasification power generation systems","volume":"10","author":"Ruether","year":"2004","journal-title":"J Infrastruct Syst"},{"key":"10.1016\/j.rser.2020.110374_bib55","doi-asserted-by":"crossref","first-page":"28","DOI":"10.1016\/j.rser.2015.12.285","article-title":"Exploring the nexus between water saving and energy conservation: insights from industry sector during the 12th Five-Year Plan period in China","volume":"59","author":"Gu","year":"2016","journal-title":"Renew Sustain Energy Rev"},{"key":"10.1016\/j.rser.2020.110374_bib56","doi-asserted-by":"crossref","first-page":"53","DOI":"10.1016\/j.applthermaleng.2009.05.005","article-title":"Pre-combustion, post-combustion and oxy-combustion in thermal power plant for CO2 capture","volume":"30","author":"Kanniche","year":"2010","journal-title":"Appl Therm Eng"},{"key":"10.1016\/j.rser.2020.110374_bib60","author":"Mancuso"},{"key":"10.1016\/j.rser.2020.110374_bib61","doi-asserted-by":"crossref","first-page":"1925","DOI":"10.1016\/j.egypro.2011.02.072","article-title":"Evaluation and analysis of water usage and loss of power in plants with CO2 capture","volume":"4","author":"Domenichini","year":"2011","journal-title":"Energy Procedia"},{"key":"10.1016\/j.rser.2020.110374_bib62","author":"Delgado"},{"key":"10.1016\/j.rser.2020.110374_bib63","author":"Marion"},{"key":"10.1016\/j.rser.2020.110374_bib66","doi-asserted-by":"crossref","first-page":"6337","DOI":"10.1016\/j.egypro.2017.03.1770","article-title":"The impact of CO2 capture on water requirements of power plants","volume":"114","author":"Magneschi","year":"2017","journal-title":"Energy Procedia"},{"key":"10.1016\/j.rser.2020.110374_bib67","doi-asserted-by":"crossref","first-page":"62","DOI":"10.1016\/j.pecs.2011.05.002","article-title":"The environmental impact and risk assessment of CO2 capture, transport and storage \u2013 an evaluation of the knowledge base","volume":"38","author":"Koornneef","year":"2012","journal-title":"Prog Energy Combust Sci"},{"key":"10.1016\/j.rser.2020.110374_bib68","doi-asserted-by":"crossref","first-page":"215","DOI":"10.1016\/j.pecs.2005.11.005","article-title":"A comparison of electricity and hydrogen production systems with CO2 capture and storage. Part A: review and selection of promising conversion and capture technologies","volume":"32","author":"Damen","year":"2006","journal-title":"Prog Energy Combust Sci"},{"key":"10.1016\/j.rser.2020.110374_bib69","series-title":"Experimental investigation on carbon dioxide absorption by aqueous ammonia in dual-path reactor","author":"Zhao","year":"2011"},{"key":"10.1016\/j.rser.2020.110374_bib70","doi-asserted-by":"crossref","first-page":"51","DOI":"10.1016\/j.eti.2017.10.002","article-title":"A preliminary analysis of increase in water use with carbon capture and storage for Indian coal-fired power plants","volume":"9","author":"Sharma","year":"2018","journal-title":"Environmental Technology & Innovation"},{"key":"10.1016\/j.rser.2020.110374_bib71","doi-asserted-by":"crossref","first-page":"651","DOI":"10.1007\/s00267-010-9434-1","article-title":"Water challenges for geologic carbon capture and sequestration","volume":"45","author":"Newmark","year":"2010","journal-title":"Environ Manag"},{"key":"10.1016\/j.rser.2020.110374_bib72","article-title":"Water & sustainability","volume":"ume 3","year":"2002"},{"key":"10.1016\/j.rser.2020.110374_bib73","doi-asserted-by":"crossref","first-page":"1","DOI":"10.1016\/j.cherd.2017.04.001","article-title":"Evaluation of cooling requirements of post-combustion CO2 capture applied to coal-fired power plants","volume":"122","author":"Brandl","year":"2017","journal-title":"Chem Eng Res Des"},{"key":"10.1016\/j.rser.2020.110374_bib74","doi-asserted-by":"crossref","DOI":"10.1088\/1748-9326\/7\/4\/045802","article-title":"Operational water consumption and withdrawal factors for electricity generating technologies: a review of existing literature","volume":"7","author":"Macknick","year":"2012","journal-title":"Environ Res Lett"},{"key":"10.1016\/j.rser.2020.110374_bib75","series-title":"Integrated environmental control model version 9.1","year":"2015"},{"key":"10.1016\/j.rser.2020.110374_bib76","doi-asserted-by":"crossref","first-page":"22","DOI":"10.1016\/j.apenergy.2018.11.050","article-title":"Placing hubs in CO2 pipelines: an application to industrial CO2 emissions in the Iberian Peninsula","volume":"236","author":"Costa","year":"2019","journal-title":"Appl Energy"},{"key":"10.1016\/j.rser.2020.110374_bib77","doi-asserted-by":"crossref","first-page":"1358","DOI":"10.1016\/j.apenergy.2019.03.141","article-title":"Experimental investigation on CO2 hydrate formation\/dissociation for cold thermal energy harvest and transportation applications","volume":"242","author":"Choi","year":"2019","journal-title":"Appl Energy"},{"key":"10.1016\/j.rser.2020.110374_bib78","doi-asserted-by":"crossref","first-page":"341","DOI":"10.1016\/j.ijggc.2012.05.008","article-title":"Costs benchmark of CO2 transport technologies for a group of various size industries","volume":"12","author":"Roussanaly","year":"2013","journal-title":"International Journal of Greenhouse Gas Control"},{"key":"10.1016\/j.rser.2020.110374_bib79","doi-asserted-by":"crossref","first-page":"523","DOI":"10.1016\/j.jclepro.2016.12.120","article-title":"A techno-economic case study of CO2 capture, transport and storage chain from a cement plant in Norway","volume":"144","author":"Jakobsen","year":"2017","journal-title":"J Clean Prod"},{"key":"10.1016\/j.rser.2020.110374_bib80","doi-asserted-by":"crossref","DOI":"10.1016\/j.rser.2019.109338","article-title":"Flexible Carbon Capture and Utilization technologies in future energy systems and the utilization pathways of captured CO2","volume":"114","author":"Mikulcic","year":"2019","journal-title":"Renew Sustain Energy Rev"},{"key":"10.1016\/j.rser.2020.110374_bib81","doi-asserted-by":"crossref","first-page":"2989","DOI":"10.1016\/j.egypro.2013.06.185","article-title":"Conceptual design of CO2 transportation system for CCS","volume":"37","author":"Suzuki","year":"2013","journal-title":"Energy Procedia"},{"key":"10.1016\/j.rser.2020.110374_bib82","doi-asserted-by":"crossref","first-page":"176","DOI":"10.1016\/j.ijggc.2016.05.010","article-title":"Budget-type techno-economic model for onshore CO2 pipeline transportation in China","volume":"51","author":"Wei","year":"2016","journal-title":"International Journal of Greenhouse Gas Control"},{"key":"10.1016\/j.rser.2020.110374_bib83","doi-asserted-by":"crossref","first-page":"66","DOI":"10.1016\/j.ijggc.2018.12.012","article-title":"Cost curve of large-scale deployment of CO2-enhanced water recovery technology in modern coal chemical industries in China","volume":"81","author":"Li","year":"2019","journal-title":"International Journal of Greenhouse Gas Control"},{"key":"10.1016\/j.rser.2020.110374_bib84","doi-asserted-by":"crossref","first-page":"330","DOI":"10.1016\/j.jclepro.2014.09.073","article-title":"CO2-EWR: a cleaner solution for coal chemical industry in China","volume":"103","author":"Li","year":"2015","journal-title":"J Clean Prod"},{"key":"10.1016\/j.rser.2020.110374_bib85","doi-asserted-by":"crossref","first-page":"555","DOI":"10.1016\/j.ijggc.2010.09.002","article-title":"Simultaneous CO2 injection and water production to optimise aquifer storage capacity","volume":"5","author":"Bergmo","year":"2011","journal-title":"International Journal of Greenhouse Gas Control"},{"key":"10.1016\/j.rser.2020.110374_bib86","doi-asserted-by":"crossref","first-page":"231","DOI":"10.1016\/j.ijggc.2012.10.012","article-title":"A preliminary sub-basin scale evaluation framework of site suitability for onshore aquifer-based CO2 storage in China","volume":"12","author":"Wei","year":"2013","journal-title":"International Journal of Greenhouse Gas Control"},{"key":"10.1016\/j.rser.2020.110374_bib87","doi-asserted-by":"crossref","first-page":"367","DOI":"10.1016\/j.petrol.2017.04.039","article-title":"Numerical simulation of a hidden fault at different stages of evolution in a carbon dioxide-enhanced saline water recovery site","volume":"154","author":"Niu","year":"2017","journal-title":"J Petrol Sci Eng"},{"key":"10.1016\/j.rser.2020.110374_bib88","doi-asserted-by":"crossref","first-page":"36","DOI":"10.1016\/j.egypro.2018.11.007","article-title":"Study on field-scale of CO2 geological storage combined with saline water recovery: a case study of east Junggar Basin of Xinjiang","volume":"154","author":"Ma","year":"2018","journal-title":"Energy Procedia"},{"key":"10.1016\/j.rser.2020.110374_bib89","first-page":"718","article-title":"Status and suggestion of environmental monitoring for CO2 geological storage","volume":"28","author":"Li","year":"2013","journal-title":"Adv Earth Sci"},{"key":"10.1016\/j.rser.2020.110374_bib90","doi-asserted-by":"crossref","first-page":"1133","DOI":"10.1016\/j.energy.2018.07.080","article-title":"Cooling towers performance in a changing climate: techno-economic modeling and design optimization","volume":"160","author":"Ayoub","year":"2018","journal-title":"Energy"},{"key":"10.1016\/j.rser.2020.110374_bib91","doi-asserted-by":"crossref","first-page":"625","DOI":"10.1016\/j.energy.2017.06.171","article-title":"Cooling limitations in power plants: optimal multiperiod design of natural draft cooling towers","volume":"135","author":"Mart\u00edn","year":"2017","journal-title":"Energy"},{"key":"10.1016\/j.rser.2020.110374_bib93","doi-asserted-by":"crossref","first-page":"430","DOI":"10.1016\/S1750-5836(07)00086-2","article-title":"CO2 storage capacity estimation: methodology and gaps","volume":"1","author":"Bachu","year":"2007","journal-title":"International Journal of Greenhouse Gas Control"},{"key":"10.1016\/j.rser.2020.110374_bib94","doi-asserted-by":"crossref","first-page":"3290","DOI":"10.1073\/pnas.1720338115","article-title":"Geospatial analysis of near-term potential for carbon-negative bioenergy in the United States","volume":"115","author":"Baik","year":"2018","journal-title":"Proc Natl Acad Sci Unit States Am"},{"key":"10.1016\/j.rser.2020.110374_bib95","doi-asserted-by":"crossref","first-page":"326","DOI":"10.1016\/j.apenergy.2018.07.117","article-title":"Carbon capture and storage (CCS) retrofit potential of coal-fired power plants in China: the technology lock-in and cost optimization perspective","volume":"229","author":"Fan","year":"2018","journal-title":"Appl Energy"},{"key":"10.1016\/j.rser.2020.110374_bib96","doi-asserted-by":"crossref","first-page":"20","DOI":"10.1016\/j.jcou.2014.12.005","article-title":"Regional resource distribution of onshore carbon geological utilization in China","volume":"11","author":"Wei","year":"2015","journal-title":"Journal of CO2 Utilization"},{"key":"10.1016\/j.rser.2020.110374_bib97","article-title":"Suitability of retrofitting CCUS to existing coal-fired power plants: a case study of former shenhua group","volume":"39","author":"Jiang","year":"2019","journal-title":"Proceedings of the CSEE"},{"key":"10.1016\/j.rser.2020.110374_bib99","first-page":"1164","article-title":"Calculation of carbon emissions from China coal plants and the reduction suggestion","volume":"23","author":"Liu","year":"2014","journal-title":"Ecology and Environmental Sciences"},{"key":"10.1016\/j.rser.2020.110374_bib100","series-title":"Research on U.S. greenhouse gas inventory compilation system","author":"Zheng","year":"2011"},{"key":"10.1016\/j.rser.2020.110374_bib101","series-title":"Calculation methods on carbon dioxide emission of Chinese coal-fired power plants","author":"Wei","year":"2014"},{"key":"10.1016\/j.rser.2020.110374_bib102","series-title":"Study on calculation model and method of carbon dioxide emissions for coal-fired power plant","author":"Long","year":"2016"},{"key":"10.1016\/j.rser.2020.110374_bib103","doi-asserted-by":"crossref","first-page":"841","DOI":"10.1016\/j.energy.2018.08.054","article-title":"Life cycle carbon emission modelling of coal-fired power: Chinese case","volume":"162","author":"Wang","year":"2018","journal-title":"Energy"}],"updated-by":[{"updated":{"date-parts":[[2022,2,1]],"date-time":"2022-02-01T00:00:00Z","timestamp":1643673600000},"DOI":"10.1016\/j.rser.2021.111901","type":"erratum","label":"Erratum"}],"container-title":["Renewable and
]}},{"indexed":{"date-parts":[[2024,3,7]],"date-time":"2024-03-07T00:13:46Z","timestamp":1709770426366},"reference-count":0,"publisher":"Chinese Chemical Society","issue":"9","content-domain":{"domain":[],"crossmark-restriction":false},"short-container-title":["CCS Chem"],"published-print":{"date-parts":[[2021,9]]},"DOI":"10.31635\/ccschem.021.202100903ed1","type":"journal-article","created":{"date-parts":[[2021,9,10]],"date-time":"2021-09-10T16:27:21Z","timestamp":1631291241000},"page":"2641-2644","source":"Crossref","is-referenced-by-count":0,"title":["Editorial"],"prefix":"10.31635","volume":"3","member":"16648","container-title":["CCS Chemistry"],"language":"en","link":[{"URL":"http:\/\/www.chinesechemsoc.org\/doi\/pdf\/10.31635\/ccschem.021.202100903ed1","content-type":"unspecified","content-version":"vor","intended-application":"similarity-checking"}],"deposited":{"date-parts":[[2024,3,6]],"date-time":"2024-03-06T09:51:04Z","timestamp":1709718664000},"score":15.677472,"resource":{"primary":{"URL":"http:\/\/www.chinesechemsoc.org\/doi\/10.31635\/ccschem.021.202100903ed1"}},"issued":{"date-parts":[[2021,9]]},"references-count":0,"journal-issue":{"issue":"9","published-print":{"date-parts":[[2021,9]]}},"alternative-id":["10.31635\/ccschem.021.202100903ed1"],"URL":"http:\/\/dx.doi.org\/10.31635\/ccschem.021.202100903ed1","ISSN":["2096-5745"],"issn-type":[{"value":"2096-5745","type":"print"}],"published":{"date-parts":[[2021,9]]}},{"indexed":{"date-parts":[[2024,3,7]],"date-time":"2024-03-07T00:14:30Z","timestamp":1709770470875},"reference-count":0,"publisher":"Chinese Chemical Society","issue":"3","content-domain":{"domain":[],"crossmark-restriction":false},"short-container-title":["CCS Chem"],"published-print":{"date-parts":[[2022,3]]},"DOI":"10.31635\/ccschem.022.202200307ed1","type":"journal-article","created":{"date-parts":[[2022,3,14]],"date-time":"2022-03-14T15:01:57Z","timestamp":1647270117000},"page":"747-750","source":"Crossref","is-referenced-by-count":0,"title":["Editorial"],"prefix":"10.31635","volume":"4","member":"16648","container-title":["CCS Chemistry"],"language":"en","link":[{"URL":"http:\/\/www.chinesechemsoc.org\/doi\/pdf\/10.31635\/ccschem.022.202200307ed1","content-type":"unspecified","content-version":"vor","intended-application":"similarity-checking"}],"deposited":{"date-parts":[[2024,3,6]],"date-time":"2024-03-06T09:52:11Z","timestamp":1709718731000},"score":15.677472,"resource":{"primary":{"URL":"http:\/\/www.chinesechemsoc.org\/doi\/10.31635\/ccschem.022.202200307ed1"}},"issued":{"date-parts":[[2022,3]]},"references-count":0,"journal-issue":{"issue":"3","published-print":{"date-parts":[[2022,3]]}},"alternative-id":["10.31635\/ccschem.022.202200307ed1"],"URL":"http:\/\/dx.doi.org\/10.31635\/ccschem.022.202200307ed1","ISSN":["2096-5745"],"issn-type":[{"value":"2096-5745","type":"print"}],"published":{"date-parts":[[2022,3]]}}],"items-per-page":20,"query":{"start-index":0,"search-terms":"\"CCS\""}}}")
# Out:
#   Cell In[54], line 1
# ...

# %%
import json
json.dumps(t)
# Out:
# '"{\'container_type\': \'Publication\', \'source\': <PublicationSource.PUBLICATION_SEARCH_SNIPPET: \'PUBLICATION_SEARCH_SNIPPET\'>, \'bib\': {\'title\': \'Public perception of carbon capture and storage (CCS): A review\', \'author\': [\'L Selma\', \'O Seigo\', \'S Dohle\', \'M Siegrist\'], \'pub_year\': \'2014\', \'venue\': \'Renewable and Sustainable \\u2026\', \'abstract\': \'this concept can be usefully applied in the CCS context. The technology is so  CCS. At the  same time, we identified two additional concepts that seem relevant in the specific case of CCS\'}, \'filled\': False, \'gsrank\': 6, \'pub_url\': \'https://www.sciencedirect.com/science/article/pii/S1364032114004699\', \'author_id\': [\'\', \'\', \'xTAYIhoAAAAJ\', \'-kPPDlQAAAAJ\'], \'url_scholarbib\': \'/scholar?hl=en&q=info:rJNbHs7aE3AJ:scholar.google.com/&output=cite&scirp=5&hl=en\', \'url_add_sclib\': \'/citations?hl=en&xsrf=&continue=/scholar%3Fq%3D%2522CCS%2522%2BOR%2B%2522CCUS%2522%2BOR%2B%2522carbon%2Bcapture%2
# ...

# %%
# Retrieve the first result from the iterator

scholarly.bibtext(next(search_query))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 3
#       1 # Retrieve the first result from the iterator
# ----> 3 scholarly.bibtext(next(search_query))
#
# AttributeError: '_Scholarly' object has no attribute 'bibtext'

# %%
from textblob import TextBlob

# %%
text='''This paper examines responses to a framing shift from carbon capture and storage (CCS) to carbon capture, utilization, and storage (CCUS) within science and engineering professionals’ communication. We argue that the framing shift is a breach in the rhetorical boundaries of the CCS professional community that calls forth negotiation through responses that proactively support, resist, or acquiesce. This study offers a heuristic for examining scientific framing in expert-to-expert internal scientific rhetoric. It also contributes to contemporary research on the intersection of rhetoric of science and science, technology, and society; the social dimensions of CCS; energy communication; and applied communicative practices in scientific communities.
'''
text='''Better stewardship of land is needed to achieve the Paris Climate Agreement goal of holding warming to below 2 °C; however, confusion persists about the specific set of land stewardship options available and their mitigation potential. To address this, we identify and quantify “natural climate solutions” (NCS): 20 conservation, restoration, and improved land management actions that increase carbon storage and/or avoid greenhouse gas emissions across global forests, wetlands, grasslands, and agricultural lands. We find that the maximum potential of NCS—when constrained by food security, fiber security, and biodiversity conservation—is 23.8 petagrams of CO2 equivalent (PgCO2e) y−1 (95% CI 20.3–37.4). This is ≥30% higher than prior estimates, which did not include the full range of options and safeguards considered here. About half of this maximum (11.3 PgCO2e y−1) represents cost-effective climate mitigation, assuming the social cost of CO2 pollution is ≥100 USD MgCO2e−1 by 2030. Natural climate solutions can provide 37% of cost-effective CO2 mitigation needed through 2030 for a >66% chance of holding warming to below 2 °C. One-third of this cost-effective NCS mitigation can be delivered at or below 10 USD MgCO2−1. Most NCS actions—if effectively implemented—also offer water filtration, flood buffering, soil health, biodiversity habitat, and enhanced climate resilience. Work remains to better constrain uncertainty of NCS mitigation estimates. Nevertheless, existing knowledge reported here provides a robust basis for immediate global action to improve ecosystem stewardship as a major solution to climate change.'''

# %%
text='''Mobilizing climate finance for climate change mitigation is a crucial part of meeting the ‘well-below’ 2°C goal of the Paris Agreement. Climate finance refers to investments specifically in climate change mitigation and adaptation activities, which involve public finance and the leveraging of private finance. A large proportion of climate finance is Official Development Assistance (ODA) from OECD countries to ODA-eligible countries. The evidence shows that the largest proportion of climate finance for climate change mitigation has been channelled to the development of renewable energy, with a much smaller proportion flowing to other crucial forms of clean energy-related measures, such as demand-side management (DSM) (particularly sustainable cooling) and carbon capture, usage and storage (CCUS). This forms the rationale and aim of this synthesis paper: to review the role of climate finance to develop clean energy beyond renewables. In doing so, the paper draws on practical policy and programme experiences of some donor countries, such as the UK, and Development Finance Institutions (DFIs). This paper argues that a greater amount of climate finance from OECD countries to ODA-eligible fossil fuel-intensive emerging economies and developing countries is required for sustainable cooling and CCUS, particularly in the form of technical assistance and clean energy innovation.'''

# %%
ab=TextBlob(text)

# %%
ab=TextBlob('''Although oil companies tout it as a way to decrease emissions, carbon capture and storage (CCS) is not a solution for climate change.''')
ab.sentiment_assessments
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])

# %%
# ccs OR "carbon capture and storage" -ccus -"carbon capture utilization and storage" -"carbon capture use and storage" -"carbon capture use and sequestration" -eor -"enhanced oil recovery"
ccs=dict(zip(list(range(2001,2024)),[525,573,692,703,941,973,1086,1204,1571,1629,2265,2152,2852,3048,2984,3217,3525,3585,3754,4064,4776,5324,5977,]))
#ccus OR "carbon capture, use and storage" OR "carbon capture, utilization and storage" OR "EOR-CCS" OR "ccs-eor" OR "carbon capture use and sequestration" OR "carbon capture utilization and sequestration" OR ("carbon capture and storage" AND "EOR")
ccus=dict(zip(list(range(2001,2024)),[176,239,214,264,285,326,321,267,400,410,496,447,590,648,550,645,986,867,955,1143,1496,2149,2673,]))
# ("carbon dioxide" OR "co2") AND ("enhanced oil recovery" OR "eor" ) -"co2 storage" -sequestration
eor=dict(zip(list(range(2001,2024)),[25,23,34,71,50,35,66,53,104,97,122,96,198,205,243,281,347,339,397,421,454,510,541,]))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(ccs.keys(),ccs.values())
plt.plot(ccus.keys(),ccus.values())
plt.plot(eor.keys(),eor.values())

# %%
# Retrieve the author's data, fill-in, and print
# Get an iterator for the author results
search_query = scholarly.search_keywords(keywords='CCS OR CCUS')
# Retrieve the first result from the iterator
first_author_result = next(search_query)
scholarly.pprint(first_author_result)

# Retrieve all the details for the author
author = scholarly.fill(first_author_result )
scholarly.pprint(author)

# Take a closer look at the first publication
first_publication = author['publications'][0]
first_publication_filled = scholarly.fill(first_publication)
scholarly.pprint(first_publication_filled)

# Print the titles of the author's publications
publication_titles = [pub['bib']['title'] for pub in author['publications']]
print(publication_titles)

# Which papers cited that publication?
abstract = [citation['bib']['abstract'] for citation in scholarly.citedby(first_publication_filled)]
print(abstract)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[90], line 7
#       5 search_query = scholarly.search_keywords(keywords='CCS OR CCUS')
#       6 # Retrieve the first result from the iterator
# ----> 7 first_author_result = next(search_query)
#       8 scholarly.pprint(first_author_result)
#      10 # Retrieve all the details for the author
#
# File ~/Library/Caches/pypoetry/virtualenvs/projects-7_KjhAaO-py3.11/lib/python3.11/site-packages/scholarly/_navigator.py:250, in Navigator.search_authors(self, url)
#     248 def search_authors(self, url: str)->Author:
#     249     """Generator that returns Author objects from the author search page"""
# --> 250     soup = self._get_soup(url)
#     252     author_parser = AuthorParser(self)
#     253     while True:
#
# ...

# %%
import pandas as pd
df=pd.read_csv('~/Downloads/eppa6/data/eppa6data.dat',delimiter='\t')

# %%
df
# Out:
#                                                 $onempty
# 0                      parameter savh0 Household saving/
# 1                                      *=>gams2prm savh0
# 2      * Called from c:\work\gtap\gtap_eppa6\model\un...
# 3                                    * 10/30/13 17:42:38
# 4                              CHN   1.6630949470062E+02
# ...                                                  ...
# 23751                     elec.REA   1.4950298532800E-02
# 23752                     elec.ANZ   2.3637477530634E-03
# 23753                     elec.MES   1.6273940472802E-02
# 23754                     elec.AFR   1.1577974406647E-01
# 23755                                                 /;
#
# [23756 rows x 1 columns]
